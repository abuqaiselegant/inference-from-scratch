# %%
import torch

# %%
import torch
a = torch.randn(4, 4)
a
# Out:
# tensor([[-1.7703,  0.5971,  1.0518, -0.1839],
#         [ 0.5886,  0.1415, -0.7086,  0.9083],
#         [-1.7647, -2.9039, -1.3884, -0.9674],
#         [ 1.1249,  0.6634,  0.5454,  0.9952]])
